# %% [markdown]
# <h1 style="text-align: center;" markdown="1">Machine Learning Algorithms for Digital Wage Payment Prediction</h1>
# <h2 style="text-align: center;" markdown="2">An AIMS Masters project in Collaboration with the Global Centre on Digital Wages for Decent Work (ILO)</h2>
#
#
# > *The widespread adoption of digital payments has become increasingly important. In light of this, the aim of this project is to investigate the probability of an individual receiving digital wages in Africa. To achieve this, a series of empirical comparative assessments of machine learning classification algorithms will be conducted. The objective is to determine the effectiveness of these algorithms in predicting digital wage payments. Therefore, this notebook forms part of a larger project that seeks to explore the potential of machine learning in addressing issues related to financial inclusion in Africa.*

# %% [markdown]
# <h1 style="text-align: center;" markdown="3">Algorithm 2 - Support Vector Machine Classifier</h1>
# <h2 style="text-align: center;" markdown="3">Part 1: Full Feature Set </h2>

# %% [markdown]
# # Table of Contents
#
# [Introduction](#setup)
# [No Sample Weights](#noweights)
# [Sample Weights](#weights)
# [Cross-Validation and Parameter Tuning](#cross-validation)
# [SVM Summary](#summary)

# %% [markdown]
# # Introduction <a class="anchor" id="setup"></a>
#
# We will now apply the Support Vector Machine classifier to the dataset.
#
# We start with loading our standard libraries and the data

# %%
# %matplotlib inline

import os
import sys

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
from IPython.display import display
import seaborn as sns
sns.set()

from sklearn.svm import SVC

# Add our local functions to the path
sys.path.append(os.path.join(os.pardir, 'src'))
from models import evaluation
from data.load_data import (get_data_filepaths, 
                            split_features_labels_weights, 
                            load_data)

from features.process_features import get_vif, standardize


ALGORITHM_NAME = 'svm'
COUNTRY = 'full_merged_dumvar'

TRAIN_PATH, TEST_PATH = get_data_filepaths(COUNTRY)

# %% [markdown]
# # No Sample Weights <a class="anchor" id="noweights"></a>
#
# Now let's apply the SVM classifier to the dataset with no weights. One of the drawbacks of SVMs is that they are very slow to train on large datasets with large numbers of features. Some of the following cells may take a long time to run.

# %%
# Load and transform the training data
X_train, y_train, w_train = load_data(TRAIN_PATH)

# Fit the model
model = SVC(probability=True)
# %time model.fit(X_train, y_train)

# Get an initial score
# %time score = model.score(X_train, y_train)
print("In-sample score: {:0.2%}".format(score))

# Load the test set
X_test, y_test, w_test = load_data(TEST_PATH)

# Run the model
y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:,1]

# from sklearn.metrics import confusion_matrix
# confusion_matrix(y_test, y_pred, sample_weight=w_test)

# Evaluate performance and store model
metrics = evaluation.evaluate_model(y_test, y_pred, y_prob,
                                    compare_models='lr_full_merged_wts',
                                    store_model=True,
                                    model_name='full_merged_simple', 
                                    prefix=ALGORITHM_NAME,
                                    country=COUNTRY,
                                    model=model,
                                    features=X_test.columns.values)
# Out:
# CPU times: user 2.94 s, sys: 11.7 ms, total: 2.95 s
# Wall time: 2.95 s
# CPU times: user 532 ms, sys: 0 ns, total: 532 ms
# Wall time: 531 ms
# In-sample score: 82.04%
# /home/socrates/.local/lib/python3.9/site-packages/sklearn/base.py:409: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# <style type="text/css">
# #T_6eb00_row0_col1, #T_6eb00_row1_col1, #T_6eb00_row2_col0, #T_6eb00_row3_col1, #T_6eb00_row4_col1, #T_6eb00_row5_col1, #T_6eb00_row6_col0 {
#   background-color: steelblue;
# }
# </style>
# <table id="T_6eb00">
#   <caption>Model Scores</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6eb00_level0_col0" class="col_heading level0 col0" >svm_full_merged_simple</th>
#       <th id="T_6eb00_level0_col1" class="col_heading level0 col1" >lr_full_merged_wts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6eb00_level0_row0" class="row_heading level0 row0" >accuracy</th>
#       <td id="T_6eb00_row0_col0" class="data row0 col0" >0.809229</td>
#       <td id="T_6eb00_row0_col1" class="data row0 col1" >0.839335</td>
#     </tr>
#     <tr>
#       <th id="T_6eb00_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_6eb00_row1_col0" class="data row1 col0" >0.819957</td>
#       <td id="T_6eb00_row1_col1" class="data row1 col1" >0.871582</td>
#     </tr>
#     <tr>
#       <th id="T_6eb00_level0_row2" class="row_heading level0 row2" >precision</th>
#       <td id="T_6eb00_row2_col0" class="data row2 col0" >0.871972</td>
#       <td id="T_6eb00_row2_col1" class="data row2 col1" >0.862065</td>
#     </tr>
#     <tr>
#       <th id="T_6eb00_level0_row3" class="row_heading level0 row3" >f1</th>
#       <td id="T_6eb00_row3_col0" class="data row3 col0" >0.845165</td>
#       <td id="T_6eb00_row3_col1" class="data row3 col1" >0.866797</td>
#     </tr>
#     <tr>
#       <th id="T_6eb00_level0_row4" class="row_heading level0 row4" >cross_entropy</th>
#       <td id="T_6eb00_row4_col0" class="data row4 col0" >0.430259</td>
#       <td id="T_6eb00_row4_col1" class="data row4 col1" >0.378029</td>
#     </tr>
#     <tr>
#       <th id="T_6eb00_level0_row5" class="row_heading level0 row5" >roc_auc</th>
#       <td id="T_6eb00_row5_col0" class="data row5 col0" >0.876288</td>
#       <td id="T_6eb00_row5_col1" class="data row5 col1" >0.905016</td>
#     </tr>
#     <tr>
#       <th id="T_6eb00_level0_row6" class="row_heading level0 row6" >cohen_kappa</th>
#       <td id="T_6eb00_row6_col0" class="data row6 col0" >0.597345</td>
#       <td id="T_6eb00_row6_col1" class="data row6 col1" >0.590324</td>
#     </tr>
#   </tbody>
# </table>
# Actual digital wage rate: 58.40%
# Predicted digital wage rate: 57.03%

# %% [markdown]
# # Sample weights <a class="anchor" id="weights">
#
# Next, we will incorporate the sample weights that came with the dataset, enabling us to generalize our model results to the overall population.

# %%
# Load and transform the training data
X_train, y_train, w_train = load_data(TRAIN_PATH)

# X_train, y_train, w_train = subsample(X_train, y_train, w_train)

# Fit the model
model = SVC(probability=True)
# %time model.fit(X_train, y_train, sample_weight=w_train)

# Get an initial score
# %time score = model.score(X_train, y_train, w_train)
print("In-sample score: {:0.2%}".format(score))

# Load the test set
X_test, y_test, w_test = load_data(TEST_PATH)

# Run the model
y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:,1]

# Evaluate performance and store model
metrics = evaluation.evaluate_model(y_test, y_pred, y_prob, w_test,
                                    compare_models=['svm_full_merged_simple', 'lr_full_merged_wts'],
                                    store_model=True,
                                    model_name='full_merged_wts', 
                                    prefix=ALGORITHM_NAME,
                                    country=COUNTRY,
                                    model=model,
                                    features=X_test.columns.values)
# Out:
# CPU times: user 5.69 s, sys: 19.4 ms, total: 5.71 s
# Wall time: 5.71 s
# CPU times: user 610 ms, sys: 78 µs, total: 610 ms
# Wall time: 609 ms
# In-sample score: 99.97%
# /home/socrates/.local/lib/python3.9/site-packages/sklearn/base.py:409: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# <style type="text/css">
# #T_2308f_row0_col1, #T_2308f_row1_col1, #T_2308f_row2_col2, #T_2308f_row3_col1, #T_2308f_row4_col1, #T_2308f_row5_col1, #T_2308f_row6_col2 {
#   background-color: steelblue;
# }
# </style>
# <table id="T_2308f">
#   <caption>Model Scores</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2308f_level0_col0" class="col_heading level0 col0" >svm_full_merged_wts</th>
#       <th id="T_2308f_level0_col1" class="col_heading level0 col1" >lr_full_merged_wts</th>
#       <th id="T_2308f_level0_col2" class="col_heading level0 col2" >svm_full_merged_simple</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2308f_level0_row0" class="row_heading level0 row0" >accuracy</th>
#       <td id="T_2308f_row0_col0" class="data row0 col0" >0.770498</td>
#       <td id="T_2308f_row0_col1" class="data row0 col1" >0.839335</td>
#       <td id="T_2308f_row0_col2" class="data row0 col2" >0.809229</td>
#     </tr>
#     <tr>
#       <th id="T_2308f_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_2308f_row1_col0" class="data row1 col0" >0.789279</td>
#       <td id="T_2308f_row1_col1" class="data row1 col1" >0.871582</td>
#       <td id="T_2308f_row1_col2" class="data row1 col2" >0.819957</td>
#     </tr>
#     <tr>
#       <th id="T_2308f_level0_row2" class="row_heading level0 row2" >precision</th>
#       <td id="T_2308f_row2_col0" class="data row2 col0" >0.821135</td>
#       <td id="T_2308f_row2_col1" class="data row2 col1" >0.862065</td>
#       <td id="T_2308f_row2_col2" class="data row2 col2" >0.871972</td>
#     </tr>
#     <tr>
#       <th id="T_2308f_level0_row3" class="row_heading level0 row3" >f1</th>
#       <td id="T_2308f_row3_col0" class="data row3 col0" >0.804892</td>
#       <td id="T_2308f_row3_col1" class="data row3 col1" >0.866797</td>
#       <td id="T_2308f_row3_col2" class="data row3 col2" >0.845165</td>
#     </tr>
#     <tr>
#       <th id="T_2308f_level0_row4" class="row_heading level0 row4" >cross_entropy</th>
#       <td id="T_2308f_row4_col0" class="data row4 col0" >0.463631</td>
#       <td id="T_2308f_row4_col1" class="data row4 col1" >0.378029</td>
#       <td id="T_2308f_row4_col2" class="data row4 col2" >0.430259</td>
#     </tr>
#     <tr>
#       <th id="T_2308f_level0_row5" class="row_heading level0 row5" >roc_auc</th>
#       <td id="T_2308f_row5_col0" class="data row5 col0" >0.852235</td>
#       <td id="T_2308f_row5_col1" class="data row5 col1" >0.905016</td>
#       <td id="T_2308f_row5_col2" class="data row5 col2" >0.876288</td>
#     </tr>
#     <tr>
#       <th id="T_2308f_level0_row6" class="row_heading level0 row6" >cohen_kappa</th>
#       <td id="T_2308f_row6_col0" class="data row6 col0" >0.465150</td>
#       <td id="T_2308f_row6_col1" class="data row6 col1" >0.590324</td>
#       <td id="T_2308f_row6_col2" class="data row6 col2" >0.597345</td>
#     </tr>
#   </tbody>
# </table>
# Actual digital wage rate: 58.40%
# Predicted digital wage rate: 57.81%

# %% [markdown]
# ## Cross-validation and Parameter Tuning <a class="anchor" id="cross-validation"></a>
#
# Now we do cross-validation when fitting the  model and try to find the best parameters through hyperparameter tuning.

# %%
from sklearn.model_selection import GridSearchCV

# Load and transform the training data
X_train, y_train, w_train = load_data(TRAIN_PATH)

# build the model
estimator = SVC(probability=True)
# parameters = {'C': 10**np.linspace(-4,1,6), 
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel': ['rbf', 'linear']}
svm_linear = {'C': [0.1, 1, 10, 100, 1000], 
              'kernel': ['linear']} 
svm_others = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001,'auto'], 
              'kernel': ['poly', 'rbf', 'sigmoid']}
parameters = [svm_linear, svm_others]
model = GridSearchCV(estimator, parameters, verbose=1, cv=5, n_jobs=-1)
# %time model.fit(X_train, y_train, sample_weight=w_train)

# Get an initial score
# %time score = model.score(X_train, y_train)
print("In-sample score: {:0.2%}".format(score))
print("Best model parameters:", model.best_params_)

# Load the test set
X_test, y_test, w_test = load_data(TEST_PATH)

# Run the model
y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:,1]

# Evaluate performance and store model
metrics = evaluation.evaluate_model(y_test, y_pred, y_prob, w_test,
                                    compare_models=['lr_full_merged_wts', 'svm_full_merged_simple', 'svm_full_merged_wts'],
                                    store_model=True,
                                    model_name='full_merged_wts_cv', 
                                    prefix=ALGORITHM_NAME,
                                    country=COUNTRY,
                                    model=model,
                                    features=X_test.columns.values)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits

# %% [markdown]
# # SVM Summary <a class="anchor" id="summary"></a>
# We have covered the basic concepts of a SVM classifier, and applied it to our dataset. We also explored some techniques for analyzing the performance of our model as well as tuning parameters.

# %%
evaluation.compare_algorithm_models(ALGORITHM_NAME, COUNTRY)
